# %%
# pandas

# %%
# series

# %%
import numpy as np
import pandas as pd

# %%
my_list = [ 10 , 20, 30 , 40 , 50]

# %%
my_labels = [ 'A' , 'B', 'C' , 'D' , 'E']

# %%
np.arr = np.array([ 10 , 20 , 30 , 40 , 50 ])

# %%
my_dict = {'A' : 10 , 'B' :20 , 'C' : 30 , 'D': 40, 'E':50}

# %%
pd.Series (data= my_list , index= my_labels)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
pd.Series(my_list , my_labels)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
pd.Series( np.arr , my_labels )
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
pd.Series([ sum , len , print ])
# Out:
# 0      <built-in function sum>
# 1      <built-in function len>
# 2    <built-in function print>
# dtype: object

# %%
# it is actually storing refrences to built in functions in the table

# %%
ser_1 = pd.Series([ 10,20,30,40,59] ,['A' , 'B' , 'C' ,'D' ,'E' ])

# %%
ser_1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    59
# dtype: int64

# %%
ser_2 = pd.Series([22,33,55,66,77],['A' , 'B ', 'C' , 'D' , 'E'])

# %%
ser_2
# Out:
# A     22
# B     33
# C     55
# D     66
# E     77
# dtype: int64

# %%
ser_1 + ser_2
# Out:
# A      32.0
# B       NaN
# B       NaN
# C      85.0
# D     106.0
# E     136.0
# dtype: float64

# %%
from numpy.random import randn
np.random.seed()

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E '.split(),columns ='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  0.006790  0.737102 -0.898030  0.383325
# B  0.612104  0.356212 -3.040366  1.161223
# C  0.735422 -0.563524  0.549484  0.263848
# D -0.236015  1.022148  1.024150  0.796738
# E  0.501212 -0.710102 -1.068123 -1.457377

# %%
df['Z']
# Out:
# A    0.383325
# B    1.161223
# C    0.263848
# D    0.796738
# E   -1.457377
# Name: Z, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['X'])
# Out:
# pandas.core.series.Series

# %%
# SO A dataframe is nothing but a combination of series

# %%
df[['X' , 'Y' ,'Z']]
# Out:
#           X         Y         Z
# A  0.737102 -0.898030  0.383325
# B  0.356212 -3.040366  1.161223
# C -0.563524  0.549484  0.263848
# D  1.022148  1.024150  0.796738
# E -0.710102 -1.068123 -1.457377

# %%
df.X
# Out:
# A    0.737102
# B    0.356212
# C   -0.563524
# D    1.022148
# E   -0.710102
# Name: X, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A  0.006790  0.737102 -0.898030  0.383325
# B  0.612104  0.356212 -3.040366  1.161223
# C  0.735422 -0.563524  0.549484  0.263848
# D -0.236015  1.022148  1.024150  0.796738
# E  0.501212 -0.710102 -1.068123 -1.457377

# %%
df['X+Y'] = df['X'] +df ['Y']

# %%
df
# Out:
#           W         X         Y         Z       X+Y
# A  0.006790  0.737102 -0.898030  0.383325 -0.160928
# B  0.612104  0.356212 -3.040366  1.161223 -2.684154
# C  0.735422 -0.563524  0.549484  0.263848 -0.014040
# D -0.236015  1.022148  1.024150  0.796738  2.046299
# E  0.501212 -0.710102 -1.068123 -1.457377 -1.778225

# %%
df['X-Y'] = df['X'] -df['Y']

# %%
df
# Out:
#           W         X         Y         Z       X+Y       X-Y
# A  0.006790  0.737102 -0.898030  0.383325 -0.160928  1.635133
# B  0.612104  0.356212 -3.040366  1.161223 -2.684154  3.396579
# C  0.735422 -0.563524  0.549484  0.263848 -0.014040 -1.113008
# D -0.236015  1.022148  1.024150  0.796738  2.046299 -0.002002
# E  0.501212 -0.710102 -1.068123 -1.457377 -1.778225  0.358021

# %%
df.drop ('X+Y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-5ce7ccf22cf4> in <module>
# ----> 1 df.drop ('X+Y')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4162             level=level,
#    4163             inplace=inplace,
# -> 4164             errors=errors,
#    4165         )
#    4166
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
# error because axis is not specified

# %%
df.drop ('E')
# Out:
#           W         X         Y         Z       X+Y       X-Y
# A  0.006790  0.737102 -0.898030  0.383325 -0.160928  1.635133
# B  0.612104  0.356212 -3.040366  1.161223 -2.684154  3.396579
# C  0.735422 -0.563524  0.549484  0.263848 -0.014040 -1.113008
# D -0.236015  1.022148  1.024150  0.796738  2.046299 -0.002002

# %%
# here axis is specified

# %%
df.drop('X-Y' , axis = 1)
# Out:
#           W         X         Y         Z       X+Y
# A  0.006790  0.737102 -0.898030  0.383325 -0.160928
# B  0.612104  0.356212 -3.040366  1.161223 -2.684154
# C  0.735422 -0.563524  0.549484  0.263848 -0.014040
# D -0.236015  1.022148  1.024150  0.796738  2.046299
# E  0.501212 -0.710102 -1.068123 -1.457377 -1.778225

# %%
df
# Out:
#           W         X         Y         Z       X+Y       X-Y
# A  0.006790  0.737102 -0.898030  0.383325 -0.160928  1.635133
# B  0.612104  0.356212 -3.040366  1.161223 -2.684154  3.396579
# C  0.735422 -0.563524  0.549484  0.263848 -0.014040 -1.113008
# D -0.236015  1.022148  1.024150  0.796738  2.046299 -0.002002
# E  0.501212 -0.710102 -1.068123 -1.457377 -1.778225  0.358021

# %%
# it appears again because inplace is set to false check documnetation for drop

# %%
df.drop('X-Y', axis=1 ,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z       X+Y
# A  0.006790  0.737102 -0.898030  0.383325 -0.160928
# B  0.612104  0.356212 -3.040366  1.161223 -2.684154
# C  0.735422 -0.563524  0.549484  0.263848 -0.014040
# D -0.236015  1.022148  1.024150  0.796738  2.046299
# E  0.501212 -0.710102 -1.068123 -1.457377 -1.778225

# %%
df.loc['A']
# Out:
# W      0.006790
# X      0.737102
# Y     -0.898030
# Z      0.383325
# X+Y   -0.160928
# Name: A, dtype: float64

# %%
# the column name becomes the index and row A is displayed

# %%
df.iloc[0]
# Out:
# W      0.006790
# X      0.737102
# Y     -0.898030
# Z      0.383325
# X+Y   -0.160928
# Name: A, dtype: float64

# %%
# above we specify the row index using integerloc

# %%
# by default all the values in pandas frame are considered float

# %%
df.loc['B' , 'X']
# Out:
# 0.3562122529324108
